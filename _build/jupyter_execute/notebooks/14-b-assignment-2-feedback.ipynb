# %% [markdown]
# # Assignment 2: Feedback
#
# In this notebook I will provide general feedback on the assignment.

# %% [markdown]
# ## Feedback
#
# - Once again, everyone submitted working code and barring small issues here and there, you have all managed to solve the questions pretty well, congratulations!
# - I am also particularly pleased that everyone seemed to have taken my previous feedback on board, which reflected in pretty much uniform improvement in grades.
# - Most submissions failed to tackle possible edge cases in Parts 2.3 & 2.5
# - While presentation was much improved, it can be improved further, e.g. with regards to conciseness and greater use of subheadings.
# - To save time, I am releasing the grades and this and personalised feedback now: please familiarise yourself with it at the start of the session and ask questions if anything seems not clear.
