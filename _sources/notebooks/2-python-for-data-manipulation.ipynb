# %% [markdown]
# # Overview: Python for data manipulation and data analysis

# %% [markdown]
# ## Introduction

# %% [markdown]
# Python is a widely used programming language for data manipulation and analysis. While Python alone is a general-purpose language, its ecosystem includes libraries that extend its functionality for data handling, computation, and visualisation.
#
# In this introductory chapter, we will provide a big picture overview of Python and showcase some of its capabalities in the context of two basic tasks for which Python is routinely used: **(a) data manipulation** and **(b) data analysis**.

# %% [markdown]
# ```{note}
# As this is an overview chapter, you are not expected to memorise every detail; the goal is to gain a general understanding. You can consider it a “guided tour” — sit back, follow along, and enjoy the concepts in action. And return to this chapter at the end of the module.

# %% [markdown]
# ### Python interpreters
#
# A Python programme consists of a set of instructions written in the Python language. To run a programme, it must be interpreted by a Python system (interpreter), which converts the code into instructions understood by the computer.
#
# Several Python systems exist, but the most widely used implementation is **CPython**, which forms the basis for most distributions.

# %% [markdown]
# ### Python in data science
#
# While Python itself can manipulate data, specialised libraries make the process efficient. For structured, table-like data, the most important library is `pandas`, which provides the `DataFrame` structure. Pandas builds on lower-level libraries such as `NumPy` and integrates easily with visualisation libraries such as `matplotlib` and `seaborn`.
#
# Together, these tools form a robust environment for data analysis.

# %% [markdown]
# ### Data manipulation
#
# Data manipulation refers to transforming data into a format that is easier to read, interpret, and use. This may involve:
#
# - Renaming variables
# - Filtering and sorting observations
# - Creating new variables
# - Handling missing values
# - Merging or reshaping datasets
#
# The `pandas` library provides efficient and intuitive functions for all these tasks.

# %% [markdown]
# ### Data analysis
#
# Data analysis is the process of examining data to uncover patterns, trends, and insights that can inform decision-making. In Python, this is typically achieved by combining `pandas` (for data handling) with visualisation tools and statistical methods.

# %% [markdown]
# <Big> Why Python for data analysis? </Big>
#
# Many tools, such as spreadsheets or dedicated statistical packages, can perform data analysis. Python stands out because it combines:
# - **Range**: it can handle both simple tasks and advanced machine learning.
# - **Reproducibility**: analysis can be written as code, making them easier to check and share.
# - **Integration**: it connects smoothly with databases, APIs (application programming interfaces), and web applications.
# - **Community**: a large set of libraries and active user support.
# - **Current relevance**: because of its popularity, Python is the language most extensively covered by modern large language models (LLMs) like ChatGPT.
#
# Other languages have their strengths—e.g. C++ for speed, Julia for both speed and elegant syntax — but Python’s popularity ensures the widest support and ecosystem (which is a bit of "vicious circle" about to be supercharged by LLMs).

# %% [markdown]
# ### Addressing the elephant in the room
#
# You might think that with tools like ChatGPT, learning Python by hand is almost pointless — after all, the model can produce working code in seconds. In the same way, these notes could have been generated by an LLM, and the exercises could be solved with its help. So why bother?
#
# The rise of AI actually makes learning to code more important, not less. Without a solid grasp of the basics, you risk blindly following outputs that can sometimes be wrong. Understanding the fundamentals gives you an edge, allowing you to check, adapt, and improve what the AI produces. **The level of understanding you should aim for is "if AI tools did not exist, I would still be able to complete the task".**
#
# Make the most of this module: challenge yourself (not to use LLMs), ask questions, interact with other students, and take advantage of being taught by someone with years of experience writing research-level mathematical software (see e.g. [PyAPD library](https://github.com/mbuze/PyAPD)).

# %% [markdown]
# ## Data manipulation in Python

# %% [markdown]
# A `DataFrame` is the primary structure for tabular data in `pandas`. It consists of rows (observations) and columns (variables), similar to a spreadsheet or database table.
#
# `pandas` provides functions to create, inspect, and manipulate `DataFrame`'s efficiently, making it a central tool for data manipulation.

# %% [markdown]
# ### Installing pandas

# %% [markdown]
# The code cell below will download and install `pandas` on your computer.

# %%
# install pandas
# !python -m pip install pandas

# %% [markdown]
# Note, that in general, a Python library can be installed using a code cell in Jupyter using the method above. The only thing that needs changing is the name of the library, which is the last part of the command.

# %% [markdown]
# To use the `pandas` library you can import it into your Python session.

# %%
import pandas as pd

# %% [markdown]
# Note that the name of the library comes after `import` and that the `as` allows the name `pandas` to be shortened to `pd` when referring to the `pandas` library in your code.

# %% [markdown]
# ### Creating a `DataFrame`

# %% [markdown]
# We can create a data frame explicitly:

# %%
df_1 = pd.DataFrame({"X" : [1,2,3], "Y" : [1,4,9]})
print(df_1)
# Out:
#    X  Y
# 0  1  1
# 1  2  4
# 2  3  9

# %% [markdown]
# or import it from an ascii file:

# %%
wings_data = pd.read_csv('./data/wings.txt',sep = "\t")
print(wings_data)
# Out:
#     Size  LocationA  LocationB
# 0      8          1          0
# 1      9          0          0
# 2     10          3          2
# 3     11          5          7
# 4     12         11         12
# 5     13         28         18
# 6     14         77         68
# 7     15         15         55
# 8     16          7         29
# 9     17          9          8
# 10    18          2          6
# 11    19          3          4
# 12    20          0          2
# 13    21          2          0
# 14    22          1          2

# %% [markdown]
# Note that the `sep='\t'` part instructs the `read_csv` function to read the file as "tab" separated. For a comma separated file use `sep = ','`.

# %% [markdown]
# #### Exercise 1

# %% [markdown]
# Load the data `pollute.txt`, located in the `data` directory, into a `DataFrame`. It is a tab separated text file.

# %%
pollute_data = pd.read_csv("./data/pollute.txt",sep='\t')

# %% [markdown]
# ### Summarising data in a `DataFrame`

# %% [markdown]
# The `pandas` library has various methods for summarising a data frame. Here are some examples.

# %%
pollute_data.head()
# Out:
#    Pollution  Temp  Industry  Population  Wind   Rain  Wet days
# 0         24  61.5       368         497   9.1  48.34       115
# 1         30  55.6       291         593   8.3  43.11       123
# 2         56  55.9       775         622   9.5  35.89       105
# 3         28  51.0       137         176   8.7  15.17        89
# 4         14  68.4       136         529   8.8  54.47       116

# %%
pollute_data.tail()
# Out:
#     Pollution  Temp  Industry  Population  Wind   Rain  Wet days
# 36         11  47.1       391         463  12.4  36.11       166
# 37         14  54.5       381         507  10.0  37.00        99
# 38         17  49.0       104         201  11.2  30.85       103
# 39         11  56.8        46         244   8.9   7.77        58
# 40         94  50.0       343         179  10.6  42.75       125

# %%
pollute_data.describe()
# Out:
#         Pollution       Temp     Industry   Population       Wind       Rain  \
# count   41.000000  41.000000    41.000000    41.000000  41.000000  41.000000
# mean    30.048780  55.763415   462.365854   608.609756   9.446341  36.771220
# std     23.472272   7.227716   563.179357   579.113023   1.423569  11.771964
# min      8.000000  43.500000    35.000000    71.000000   6.000000   7.050000
# 25%     13.000000  50.600000   181.000000   299.000000   8.700000  30.960000
# 50%     26.000000  54.600000   347.000000   515.000000   9.300000  38.740000
# 75%     35.000000  59.300000   462.000000   717.000000  10.600000  43.110000
# max    110.000000  75.500000  3344.000000  3369.000000  12.700000  59.800000
#
#          Wet days
# count   41.000000
# mean   113.902439
# std     26.506419
# min     36.000000
# 25%    103.000000
# 50%    115.000000
# 75%    128.000000
# max    166.000000

# %% [markdown]
# Note that the variable associated with a data frame can be used to call methods (functions, algorithms) that work with data frames. Generally, a variable `var` can use a method `method` taking arguments `args` using the syntax
#
# `var.method(args)`

# %% [markdown]
# ### Using `help` function

# %% [markdown]
# You can use the help function to explore information about `pandas` objects and methods. For example, to learn more about `DataFrames` (warning: this is very long text):

# %%
help(pd.DataFrame)
# Out:
# Help on class DataFrame in module pandas.core.frame:
#
# class DataFrame(pandas.core.generic.NDFrame, pandas.core.arraylike.OpsMixin)
#  |  DataFrame(data=None, index: 'Axes | None' = None, columns: 'Axes | None' = None, dtype: 'Dtype | None' = None, copy: 'bool | None' = None)
#  |
#  |  Two-dimensional, size-mutable, potentially heterogeneous tabular data.
#  |
#  |  Data structure also contains labeled axes (rows and columns).
#  |  Arithmetic operations align on both row and column labels. Can be
#  |  thought of as a dict-like container for Series objects. The primary
#  |  pandas data structure.
#  |
#  |  Parameters
#  |  ----------
#  |  data : ndarray (structured or homogeneous), Iterable, dict, or DataFrame
#  |      Dict can contain Series, arrays, constants, dataclass or list-like objects. If
#  |      data is a dict, column order follows insertion-order. If a dict contains Series
#  |      which have an index defined, it is aligned by its index.
#  |
# ...

# %% [markdown]
# Note that the `help` function takes as an argument the name of the object or method you want information about. This can be a class or function from the `pandas` library (e.g. `DataFrame`) or an instance of such an object.

# %%
help(pollute_data)
# Out:
# Help on DataFrame in module pandas.core.frame object:
#
# class DataFrame(pandas.core.generic.NDFrame, pandas.core.arraylike.OpsMixin)
#  |  DataFrame(data=None, index: 'Axes | None' = None, columns: 'Axes | None' = None, dtype: 'Dtype | None' = None, copy: 'bool | None' = None)
#  |
#  |  Two-dimensional, size-mutable, potentially heterogeneous tabular data.
#  |
#  |  Data structure also contains labeled axes (rows and columns).
#  |  Arithmetic operations align on both row and column labels. Can be
#  |  thought of as a dict-like container for Series objects. The primary
#  |  pandas data structure.
#  |
#  |  Parameters
#  |  ----------
#  |  data : ndarray (structured or homogeneous), Iterable, dict, or DataFrame
#  |      Dict can contain Series, arrays, constants, dataclass or list-like objects. If
#  |      data is a dict, column order follows insertion-order. If a dict contains Series
#  |      which have an index defined, it is aligned by its index.
#  |
# ...

# %% [markdown]
# To determine the type of an object in Python, you can use the `type` function. For example:

# %%
type(pollute_data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Another way to obtain guidance on using a Python library is through its official documentation. For `pandas`, the full documentation is available [here](https://pandas.pydata.org/docs/).

# %% [markdown]
# #### Exercise 2
#
# Explore the purpose of the `cumsum` and `corr` methods for `DataFrame` objects, and apply them to `pollute_data`.

# %%
help(pd.DataFrame.corr)
# Out:
# Help on function corr in module pandas.core.frame:
#
# corr(self, method: 'str | Callable[[np.ndarray, np.ndarray], float]' = 'pearson', min_periods: 'int' = 1) -> 'DataFrame'
#     Compute pairwise correlation of columns, excluding NA/null values.
#
#     Parameters
#     ----------
#     method : {'pearson', 'kendall', 'spearman'} or callable
#         Method of correlation:
#
#         * pearson : standard correlation coefficient
#         * kendall : Kendall Tau correlation coefficient
#         * spearman : Spearman rank correlation
#         * callable: callable with input two 1d ndarrays
#             and returning a float. Note that the returned matrix from corr
#             will have 1 along the diagonals and will be symmetric
#             regardless of the callable's behavior.
#     min_periods : int, optional
#         Minimum number of observations required per pair of columns
#         to have a valid result. Currently only available for Pearson
# ...

# %%
help(pd.DataFrame.cumsum)
# Out:
# Help on function cumsum in module pandas.core.generic:
#
# cumsum(self, axis=None, skipna=True, *args, **kwargs)
#     Return cumulative sum over a DataFrame or Series axis.
#
#     Returns a DataFrame or Series of the same size containing the cumulative
#     sum.
#
#     Parameters
#     ----------
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         The index or the name of the axis. 0 is equivalent to None or 'index'.
#     skipna : bool, default True
#         Exclude NA/null values. If an entire row/column is NA, the result
#         will be NA.
#     *args, **kwargs
#         Additional keywords have no effect but might be accepted for
#         compatibility with NumPy.
#
#     Returns
#     -------
#     Series or DataFrame
#         Return cumulative sum of Series or DataFrame.
#
#     See Also
#     --------
#     core.window.Expanding.sum : Similar functionality
#         but ignores ``NaN`` values.
#     DataFrame.sum : Return the sum over
# ...

# %%
pollute_data.corr()
# Out:
#             Pollution      Temp  Industry  Population      Wind      Rain  \
# Pollution    1.000000 -0.433600  0.645165    0.493780  0.095099  0.054284
# Temp        -0.433600  1.000000 -0.187882   -0.062678 -0.351123  0.386280
# Industry     0.645165 -0.187882  1.000000    0.955458  0.236506 -0.031217
# Population   0.493780 -0.062678  0.955458    1.000000  0.211772 -0.026069
# Wind         0.095099 -0.351123  0.236506    0.211772  1.000000 -0.012466
# Rain         0.054284  0.386280 -0.031217   -0.026069 -0.012466  1.000000
# Wet days     0.369564 -0.430242  0.130738    0.042083  0.166950  0.496058
#
#             Wet days
# Pollution   0.369564
# Temp       -0.430242
# Industry    0.130738
# Population  0.042083
# Wind        0.166950
# Rain        0.496058
# Wet days    1.000000

# %%
pollute_data.cumsum()
# Out:
#     Pollution    Temp  Industry  Population   Wind     Rain  Wet days
# 0          24    61.5       368         497    9.1    48.34       115
# 1          54   117.1       659        1090   17.4    91.45       238
# 2         110   173.0      1434        1712   26.9   127.34       343
# 3         138   224.0      1571        1888   35.6   142.51       432
# 4         152   292.4      1707        2417   44.4   196.98       548
# 5         198   340.0      1751        2533   53.2   230.34       683
# 6         207   406.2      2392        3377   64.1   266.28       761
# 7         242   456.1      3456        4890   74.2   297.24       890
# 8         268   513.9      3653        5189   81.8   339.83      1005
# 9         329   564.3      4000        5709   91.2   376.05      1152
# 10        358   621.6      4434        6466  100.5   415.03      1263
# 11        386   673.9      4795        7212  110.2   453.77      1384
# ...

# %% [markdown]
# ### Accessing data in a `DataFrame`

# %% [markdown]
# Here are several ways to access and subset data within a DataFrame. The examples below illustrate some of the most commonly used methods.
#
# Most of these are relatively straightforward. The details of how and why each method works will be explained in more depth later.

# %% [markdown]
# <Big> By column name </Big>

# %%
pollute_data[['Temp','Wind']]
# Out:
#     Temp  Wind
# 0   61.5   9.1
# 1   55.6   8.3
# 2   55.9   9.5
# 3   51.0   8.7
# 4   68.4   8.8
# 5   47.6   8.8
# 6   66.2  10.9
# 7   49.9  10.1
# 8   57.8   7.6
# 9   50.4   9.4
# 10  57.3   9.3
# 11  52.3   9.7
# 12  51.5  10.9
# 13  59.4   7.9
# 14  51.9   9.0
# 15  54.0   7.1
# 16  55.0   9.6
# 17  61.0   8.2
# 18  55.2   6.6
# 19  56.7   8.7
# 20  70.3   6.0
# 21  50.6  10.4
# 22  49.1   9.0
# 23  68.9  10.8
# 24  54.6   9.6
# 25  56.6  12.7
# 26  54.0   9.0
# 27  45.7  11.8
# 28  51.1   9.4
# 29  43.5  10.6
# 30  49.7  10.9
# 31  68.3   8.4
# 32  75.5   9.0
# 33  51.5   8.6
# 34  59.3  10.6
# 35  61.6   9.2
# 36  47.1  12.4
# 37  54.5  10.0
# 38  49.0  11.2
# 39  56.8   8.9
# 40  50.0  10.6

# %% [markdown]
# <Big> By row number  </Big>

# %%
pollute_data.iloc[2:7]
# Out:
#    Pollution  Temp  Industry  Population  Wind   Rain  Wet days
# 2         56  55.9       775         622   9.5  35.89       105
# 3         28  51.0       137         176   8.7  15.17        89
# 4         14  68.4       136         529   8.8  54.47       116
# 5         46  47.6        44         116   8.8  33.36       135
# 6          9  66.2       641         844  10.9  35.94        78

# %% [markdown]
# <Big> By row number and column name  </Big>

# %%
pollute_data[2:7][['Temp','Rain']]
# Out:
#    Temp   Rain
# 2  55.9  35.89
# 3  51.0  15.17
# 4  68.4  54.47
# 5  47.6  33.36
# 6  66.2  35.94

# %% [markdown]
# <Big> By row number and column number  </Big>

# %%
pollute_data.iloc[2:7][3:7]
# Out:
#    Pollution  Temp  Industry  Population  Wind   Rain  Wet days
# 5         46  47.6        44         116   8.8  33.36       135
# 6          9  66.2       641         844  10.9  35.94        78

# %%
pollute_data.iloc[[1,4,5]][1:3]
# Out:
#    Pollution  Temp  Industry  Population  Wind   Rain  Wet days
# 4         14  68.4       136         529   8.8  54.47       116
# 5         46  47.6        44         116   8.8  33.36       135

# %% [markdown]
# <Big> Using a logical condition </Big>

# %%
pollute_data[pollute_data['Wind'] > 10.0]
# Out:
#     Pollution  Temp  Industry  Population  Wind   Rain  Wet days
# 6           9  66.2       641         844  10.9  35.94        78
# 7          35  49.9      1064        1513  10.1  30.96       129
# 12         14  51.5       181         347  10.9  30.18        98
# 21        110  50.6      3344        3369  10.4  34.44       122
# 23         10  68.9       721        1233  10.8  48.19       103
# 25          8  56.6       125         277  12.7  30.58        82
# 27         16  45.7       569         717  11.8  29.07       123
# 29         29  43.5       669         744  10.6  25.94       137
# 30         65  49.7      1007         751  10.9  34.99       155
# 34         31  59.3        96         308  10.6  44.68       116
# 36         11  47.1       391         463  12.4  36.11       166
# 38         17  49.0       104         201  11.2  30.85       103
# 40         94  50.0       343         179  10.6  42.75       125

# %% [markdown]
# ### Visualising data

# %% [markdown]
# #### With `matplotlib` library
#
# The `pandas` library includes some methods for visualising `DataFrame` data. However, most of these rely on the `matplotlib` library and will not work unless it is installed on your system. To install `matplotlib`, run the following command in a code cell:

# %%
# !python -m pip install matplotlib

# %% [markdown]
# Here is a showcase of possible plots:

# %%
pollute_data.plot()
# Out:
# <AxesSubplot:>

# %%
pollute_data.plot(subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
pollute_data.plot.bar()
# Out:
# <AxesSubplot:>

# %%
pollute_data.plot.box()
# Out:
# <Axes: >

# %% [markdown]
# ##### Exercise 3
#
# Use the `help` function to find more information on the `plot` method for a `DataFrame` object from `pandas`. Use this information to experiment with some different plot types, and see if you can add any extra information to your plots.

# %%
help(pd.DataFrame.plot)
# Out:
# Help on class PlotAccessor in module pandas.plotting._core:
#
# class PlotAccessor(pandas.core.base.PandasObject)
#  |  PlotAccessor(data)
#  |
#  |  Make plots of Series or DataFrame.
#  |
#  |  Uses the backend specified by the
#  |  option ``plotting.backend``. By default, matplotlib is used.
#  |
#  |  Parameters
#  |  ----------
#  |  data : Series or DataFrame
#  |      The object for which the method is called.
#  |  x : label or position, default None
#  |      Only used if data is a DataFrame.
#  |  y : label, position or list of label, positions, default None
#  |      Allows plotting of one column versus another. Only used if data is a
#  |      DataFrame.
#  |  kind : str
#  |      The kind of plot to produce:
#  |
#  |      - 'line' : line plot (default)
#  |      - 'bar' : vertical bar plot
#  |      - 'barh' : horizontal bar plot
#  |      - 'hist' : histogram
#  |      - 'box' : boxplot
#  |      - 'kde' : Kernel Density Estimation plot
# ...

# %%
pollute_data.plot.area(title = "Area under the curve");

# %% [markdown]
# #### With `seaborn` library

# %% [markdown]
# The plotting in the `pandas` library can be useful, but has limited scope (the library focusses on organising and manipulating data). On the other hand the `seaborn` library is specifically for data visualisation, and has been designed to work well with `DataFrame` objects from `pandas`.

# %% [markdown]
# ##### Exercise 4
#
# Install the `seaborn` library.

# %%
# !python -m pip install seaborn

# %% [markdown]
# Here is some example usage:

# %%
import seaborn

# %%
seaborn.pairplot(pollute_data)

# %%
seaborn.heatmap(pollute_data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
seaborn.set_theme(style="ticks")
seaborn.boxplot(pollute_data)
seaborn.stripplot(pollute_data)
seaborn.despine(trim=True, left=True)

# %%
seaborn.violinplot(pollute_data[['Industry','Population','Pollution']])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### Exercise 5
#
# Browse the [Seaborn gallery](https://seaborn.pydata.org/examples/index.html) and experiment with creating a few different types of plots.

# %% [markdown]
# ## Data analysis in Python

# %% [markdown]
# While `pandas` and `seaborn` are great at manipulating and visualising data, other libraries are typically used to analyse the data. In this section we will showcase the capabilities of `statsmodels` and `scipy` libraries.

# %% [markdown]
# #### Exercise 6
#
# Install the `scipy` and `statsmodels` libraries. Details of these libraries can be found on the [SciPy](https://scipy.org/) and [statsmodels](https://www.statsmodels.org/stable/index.html).

# %%
# !python -m pip install statsmodels

# %%
# !python -m pip install scipy

# %% [markdown]
# ### Ordinary least squares regression with statsmodels

# %% [markdown]
# This example examines a regression of population against industry. With `statsmodels`, you first create a model before fitting it to the data.

# %%
import statsmodels.formula.api as smf

# %%
pollute_model = smf.ols('Population ~ Industry', data=pollute_data)

# %% [markdown]
# We can once again use `help` to gain insight:

# %%
help(pollute_model)
# Out:
# Help on OLS in module statsmodels.regression.linear_model object:
#
# class OLS(WLS)
#  |  OLS(endog, exog=None, missing='none', hasconst=None, **kwargs)
#  |
#  |  Ordinary Least Squares
#  |
#  |  Parameters
#  |  ----------
#  |  endog : array_like
#  |      A 1-d endogenous response variable. The dependent variable.
#  |  exog : array_like
#  |      A nobs x k array where `nobs` is the number of observations and `k`
#  |      is the number of regressors. An intercept is not included by default
#  |      and should be added by the user. See
#  |      :func:`statsmodels.tools.add_constant`.
#  |  missing : str
#  |      Available options are 'none', 'drop', and 'raise'. If 'none', no nan
#  |      checking is done. If 'drop', any observations with nans are dropped.
#  |      If 'raise', an error is raised. Default is 'none'.
#  |  hasconst : None or bool
#  |      Indicates whether the RHS includes a user-supplied constant. If True,
# ...

# %% [markdown]
# First, notice how the model is specified using the string 'Population ~ Industry'. The formula is used to generate components such as the design matrix, but the model is not fitted at this stage. To explore what the model contains, you can use Python’s `dir` function.

# %%
dir(pollute_model)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_check_kwargs',
#  '_data_attr',
#  '_df_model',
#  '_df_resid',
#  '_fit_collinear',
#  '_fit_ridge',
#  '_fit_zeros',
#  '_formula_max_endog',
#  '_get_init_kwds',
#  '_handle_data',
#  '_init_keys',
#  '_kwargs_allowed',
#  '_setup_score_hess',
#  '_sqrt_lasso',
#  'data',
#  'df_model',
#  'df_resid',
#  'endog',
#  'endog_names',
#  'exog',
#  'exog_names',
#  'fit',
#  'fit_regularized',
#  'formula',
#  'from_formula',
#  'get_distribution',
#  'hessian',
#  'hessian_factor',
#  'information',
#  'initialize',
#  'k_constant',
#  'loglike',
# ...

# %% [markdown]
# One of the methods, `fit`, fits the model to the data.

# %%
pollute_fit = pollute_model.fit()

# %% [markdown]
# #### Exercise 7
#
# Find out what methods are associated with the object referred to by the variable `pollute_fit`

# %%
help(pollute_fit)
# Out:
# Help on RegressionResultsWrapper in module statsmodels.regression.linear_model:
#
# <statsmodels.regression.linear_model.RegressionResultsWrapper object>
#     Results class for for an OLS model.
#
#     Parameters
#     ----------
#     model : RegressionModel
#         The regression model instance.
#     params : ndarray
#         The estimated parameters.
#     normalized_cov_params : ndarray
#         The normalized covariance parameters.
#     scale : float
#         The estimated scale of the residuals.
#     cov_type : str
#         The covariance estimator used in the results.
#     cov_kwds : dict
#         Additional keywords used in the covariance specification.
#     use_t : bool
#         Flag indicating to use the Student's t in inference.
#     **kwargs
#         Additional keyword arguments used to initialize the results.
#
#     See Also
#     --------
#     RegressionResults
#         Results store for WLS and GLW models.
#
#     Notes
#     -----
# ...

# %%
dir(pollute_fit)
# Out:
# ['HC0_se',
#  'HC1_se',
#  'HC2_se',
#  'HC3_se',
#  '_HCCM',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abat_diagonal',
#  '_cache',
#  '_data_attr',
#  '_data_in_cache',
#  '_get_robustcov_results',
#  '_get_wald_nonlinear',
#  '_is_nested',
#  '_transform_predict_exog',
#  '_use_t',
#  '_wexog_singular_values',
#  'aic',
#  'bic',
#  'bse',
#  'centered_tss',
#  'compare_f_test',
#  'compare_lm_test',
#  'compare_lr_test',
#  'condition_number',
#  'conf_int',
#  'conf_int_el',
#  'cov_HC0',
#  'cov_HC1',
#  'cov_HC2',
#  'cov_HC3',
#  'cov_kwds',
#  'cov_params',
#  'cov_type',
# ...

# %% [markdown]
# We can display the summary of the model and the fit by invoking:

# %%
pollute_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Population   R-squared:                       0.913
# Model:                            OLS   Adj. R-squared:                  0.911
# Method:                 Least Squares   F-statistic:                     408.8
# Date:                Mon, 22 Sep 2025   Prob (F-statistic):           2.84e-22
# Time:                        20:47:28   Log-Likelihood:                -268.46
# No. Observations:                  41   AIC:                             540.9
# Df Residuals:                      39   BIC:                             544.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    154.3400     35.151      4.391      0.000      83.241     225.439
# ...

# %% [markdown]
# #### Plotting results

# %% [markdown]
# Like `pandas`, `statsmodels` also has some built-in visualisation functionalities.

# %%
import statsmodels.api as sm

# %%
sm.graphics.plot_regress_exog(pollute_fit, "Industry").tight_layout(pad=1.0)

# %%
sm.qqplot(pollute_fit.resid);

# %%
sm.graphics.plot_fit(pollute_fit,"Industry");

# %% [markdown]
# ### Hypothesis testing with `scipy`

# %% [markdown]
# The `statsmodels` library is very useful for building data models, but for hypothesis testing, the `scipy` library is generally preferred.

# %% [markdown]
# #### Kolmogorov-Smirnov tests

# %% [markdown]
# The wings data set contains count data for the size of insects wings from two different locations.

# %%
wings_data
# Out:
#     Size  LocationA  LocationB
# 0      8          1          0
# 1      9          0          0
# 2     10          3          2
# 3     11          5          7
# 4     12         11         12
# 5     13         28         18
# 6     14         77         68
# 7     15         15         55
# 8     16          7         29
# 9     17          9          8
# 10    18          2          6
# 11    19          3          4
# 12    20          0          2
# 13    21          2          0
# 14    22          1          2

# %% [markdown]
# This example tests the hypothesis that the distribution of wing sizes from the two locations are the same.

# %%
import scipy

# %%
res = scipy.stats.kstest(wings_data['LocationA'],wings_data['LocationB'])
print(res)
# Out:
# KstestResult(statistic=np.float64(0.13333333333333333), pvalue=np.float64(0.9997887537139585), statistic_location=np.int64(11), statistic_sign=np.int8(1))

# %% [markdown]
# #### Exercise 8
#
# The file `f.test.data.txt` in the data directory has data regarding the ozone levels measured in two market gardens. Th file is tab separated.
#
# 1) Load the data in to a `pandas` data frame.
# 2) Find a suitable `DataFrame` method to calculate the variance of the two samples.
# 3) Find out how to calculate an F-statistic using `scipy`
# 4) Use your results from 2) and 3) to undertake a Fishers F test on the ozone data
# 5) Find out how to do a Levene test using `scipy`
# 6) Compare your results from part 4) and 5).

# %%
ozone_data = pd.read_csv('./data/f.test.data.txt',sep='\t')
print(ozone_data)
# Out:
#    gardenB  gardenC
# 0        5        3
# 1        5        3
# 2        6        2
# 3        7        1
# 4        4       10
# 5        4        4
# 6        3        3
# 7        5       11
# 8        6        3
# 9        5       10

# %%
ozone_describe = ozone_data.describe()
dfd = ozone_describe.iloc[0][0] - 1
dfn = ozone_describe.iloc[0][1] - 1
ratio = ozone_data.var()[1]/ozone_data.var()[0]
p_value = 2*(1-scipy.stats.f.cdf(ratio,dfn,dfd))
print(p_value)
# Out:
# 0.001624198931373888

# %%
ozone_data.var()[0]
# Out:
# 1.3333333333333333

# %%
scipy.stats.levene(ozone_data['gardenB'],ozone_data['gardenC'])
# Out:
# LeveneResult(statistic=2.750943396226415, pvalue=0.11452047245753871)
